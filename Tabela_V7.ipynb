# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: C:\Users\Alice\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: C:\Users\Alice\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Preparação dos dados

# %%
# Importação da biblioteca pandas para manipulação de dados
import pandas as pd

# Caminhos para os arquivos CSV
file_path = './csv_recebidos/Distâncias_aeroportos.csv'  # Arquivo com as distâncias entre aeroportos
file_path1 = './csv_recebidos/Nome_Aeroporto.csv'  # Arquivo com os nomes dos aeroportos

# Carrega os arquivos CSV em DataFrames
df = pd.read_csv(file_path)  # DataFrame com as distâncias
df_nome = pd.read_csv(file_path1)  # DataFrame com os nomes dos aeroportos

df
# Out:
#       InputID  TargetID  Distance (km)
# 0           1         2           2095
# 1           1         3           1448
# 2           1         4           2294
# 3           1         5           2318
# 4           1         6           2337
# ...       ...       ...            ...
# 8005       91        85           2625
# 8006       91        86           3045
# 8007       91        88           7255
# 8008       91        89           6897
# 8009       91        90            902
#
# [8010 rows x 3 columns]

# %%
# Renomeia as colunas do DataFrame de distâncias
df.columns = ["InputID", "TargetID", "Distância km"]
df
# Out:
#       InputID  TargetID  Distância km
# 0           1         2          2095
# 1           1         3          1448
# 2           1         4          2294
# 3           1         5          2318
# 4           1         6          2337
# ...       ...       ...           ...
# 8005       91        85          2625
# 8006       91        86          3045
# 8007       91        88          7255
# 8008       91        89          6897
# 8009       91        90           902
#
# [8010 rows x 3 columns]

# %%
# Cria um mapeamento de IDs para nomes dos aeroportos
mapa_ids = {i+1: nome for i, nome in enumerate(df_nome['Aeroporto'])}

# Substitui os IDs nas colunas 'InputID' e 'TargetID' pelos nomes dos aeroportos
df['InputID'] = df['InputID'].replace(mapa_ids)
df['TargetID'] = df['TargetID'].replace(mapa_ids)
# Adiciona uma coluna de emissão de CO2 com base na distância

df
# Out:
#                                      InputID  \
# 0       Aeroporto Internacional de Guarulhos
# 1       Aeroporto Internacional de Guarulhos
# 2       Aeroporto Internacional de Guarulhos
# 3       Aeroporto Internacional de Guarulhos
# 4       Aeroporto Internacional de Guarulhos
# ...                                      ...
# 8005  Aeroporto Internacional de João Pessoa
# 8006  Aeroporto Internacional de João Pessoa
# 8007  Aeroporto Internacional de João Pessoa
# 8008  Aeroporto Internacional de João Pessoa
# 8009  Aeroporto Internacional de João Pessoa
#
#                                                TargetID  Distância km
# 0                     Aeroporto Internacional do Recife          2095
# 1                   Aeroporto Internacional de Salvador          1448
# 2                      Aeroporto Internacional de Natal          2294
# 3                   Aeroporto Internacional de São Luís          2318
# ...

# %%
# Função para formatar horas no formato HH:MM
def format_time(hours):
    h = int(hours)
    m = int((hours - h) * 60)
    return f"{h:02}:{m:02}"

# Calcula o tempo médio de voo para aeronaves comerciais
df['Tempo Médio Horas - Comercial'] = df['Distância km'].apply(
    lambda d: f"{format_time(d / 900)} ~ {format_time(d / 850)}"
)

# Calcula o tempo médio de voo para aeronaves cargueiras
df['Tempo Médio Horas - Cargueiro'] = df['Distância km'].apply(
    lambda d: f"{format_time(d / 850)} ~ {format_time(d / 800)}"
)

df.to_csv('./csv_gerado/Tabela_Básica.csv', index=False)

# %%
df
# Out:
#                                      InputID  \
# 0       Aeroporto Internacional de Guarulhos
# 1       Aeroporto Internacional de Guarulhos
# 2       Aeroporto Internacional de Guarulhos
# 3       Aeroporto Internacional de Guarulhos
# 4       Aeroporto Internacional de Guarulhos
# ...                                      ...
# 8005  Aeroporto Internacional de João Pessoa
# 8006  Aeroporto Internacional de João Pessoa
# 8007  Aeroporto Internacional de João Pessoa
# 8008  Aeroporto Internacional de João Pessoa
# 8009  Aeroporto Internacional de João Pessoa
#
#                                                TargetID  Distância km  \
# 0                     Aeroporto Internacional do Recife          2095
# 1                   Aeroporto Internacional de Salvador          1448
# 2                      Aeroporto Internacional de Natal          2294
# 3                   Aeroporto Internacional de São Luís          2318
# ...

# %%
# Lista de aeroportos de interesse
aeroportos_interesse = [
    "Aeroporto Internacional de Guarulhos",
    "Aeroporto Internacional do Recife",
    "Aeroporto Internacional de Salvador",
    "Aeroporto Internacional de Natal",
    "Aeroporto Internacional de São Luís",
    "Aeroporto Internacional de Fortaleza",
    "Aeroporto Internacional de Brasília",
    "Aeroporto Internacional de Várzea Grande",
    "Aeroporto Internacional de Belém",
    "Aeroporto Internacional de Tabatinga",
    "Aeroporto Internacional de Manaus",
    "Aeroporto Internacional de Macapá",
    "Aeroporto Internacional de Maceió",
    "Aeroporto Internacional de Aracaju",
    "Aeroporto Internacional de Belo Horizonte",
    "Aeroporto Santos Dumont",
    "Aeroporto Internacional do Rio de Janeiro",
    "Aeroporto Internacional de Vitória",
    "Aeroporto Internacional de São José dos Campos",
    "Aeroporto Internacional de Viracopos",
    "Aeroporto Internacional de Curitiba",
    "Aeroporto Internacional de Florianópolis",
    "Aeroporto Internacional de Navegantes",
    "Aeroporto Internacional de Porto Alegre",
    "Aeroporto Internacional de Boa Vista",
    "Aeroporto de Teresina",
    "Aeroporto Internacional de João Pessoa",
    "Aeroporto Jorge Amado"
]

# Gera uma lista de aeroportos de origem únicos
lista_origem = df['InputID'].unique().tolist()

# Remove os aeroportos de interesse da lista de origem
for i in aeroportos_interesse:
    try:
        lista_origem.remove(i)
    except ValueError:
        pass

lista_origem
# Out:
# ['Aeroporto Internacional Pinto Martins',
#  'Aeroporto Internacional de Nursultan Nazarbayev',
#  'Aeroporto Internacional de Xangai Pudong',
#  'Aeroporto Internacional de Pequim Capital',
#  'Aeroporto Internacional de Pyongyang Sunan',
#  'Aeroporto Internacional de Incheon',
#  'Aeroporto Internacional Ninoy Aquino',
#  'Aeroporto Internacional de Hong Kong',
#  'Aeroporto Internacional Indira Gandhi',
#  'Aeroporto Internacional Soekarno-Hatta (Jacarta)',
#  'Aeroporto Internacional Ngurah Rai (Bali)',
#  'Aeroporto Internacional de Narita (Tóquio)',
#  'Aeroporto Internacional de Haneda (Tóquio)',
#  'Aeroporto Internacional de Kansai (Osaka)',
#  'Aeroporto Internacional de Wattay (Vientiane)',
#  'Aeroporto Internacional de Kuala Lumpur (Sepang)',
#  'Aeroporto Internacional de Penang (Penang)',
#  'Aeroporto Internacional de Malé',
#  'Aeroporto Internacional de Changi',
#  'Aeroporto Internacional de Suvarnabhumi',
#  'Aeroporto Internacional Don Mueang',
# ...

# %%
aeroportos_estado = {
    "Alagoas": ["Aeroporto Internacional de Maceió"],
    "Amapá": ["Aeroporto Internacional de Macapá"],
    "Amazonas": [
        "Aeroporto Internacional de Tabatinga",
        "Aeroporto Internacional de Manaus"
    ],
    "Bahia": ["Aeroporto Internacional de Salvador"],
    "Bahia-Ilhéus": ["Aeroporto Jorge Amado"],
    "Ceará": ["Aeroporto Internacional de Fortaleza"],
    "Espírito Santo": ["Aeroporto Internacional de Vitória"],
    "Maranhão": ["Aeroporto Internacional de São Luís"],
    "Mato Grosso": ["Aeroporto Internacional de Brasília"],
    "Minas Gerais": ["Aeroporto Internacional de Belo Horizonte"],
    "Pará": ["Aeroporto Internacional de Belém"],
    "Paraíba" : ["Aeroporto Internacional de João Pessoa"],
    "Paraná": ["Aeroporto Internacional de Curitiba"],
    "Pernambuco": ["Aeroporto Internacional do Recife"],
    "Piauí": ["Aeroporto de Teresina"],
    "Rio de Janeiro": [
        "Aeroporto Santos Dumont",
        "Aeroporto Internacional do Rio de Janeiro"
    ],
    "Rio Grande do Norte": ["Aeroporto Internacional de Natal"],
    "Rio Grande do Sul": ["Aeroporto Internacional de Porto Alegre"],
    "Roraima": ["Aeroporto Internacional de Boa Vista"],
    "Santa Catarina": [
        "Aeroporto Internacional de Florianópolis",
        "Aeroporto Internacional de Navegantes"
    ],
    "São Paulo": [
        "Aeroporto Internacional de Guarulhos",
        "Aeroporto Internacional de São José dos Campos",
        "Aeroporto Internacional de Viracopos"
    ],
    "Sergipe": ["Aeroporto Internacional de Aracaju"]
}

# %% [markdown]
# # Tabela completa

# %%
# Lista para armazenar os resultados
result = []

# Itera sobre todos os aeroportos de origem na lista_origem
for aeroporto_origem in lista_origem:
    # Inicializa um dicionário para armazenar os dados de cada aeroporto de destino
    dados_aeroportos = {estado_destino: [None, None, None] for estado_destino in aeroportos_estado.keys()}
    
    # Itera sobre os aeroportos de destino
    for estado_destino, aeroporto_destino in aeroportos_estado.items():
        # Seleciona a linha com informações sobre o aeroporto de origem e destino
        linha = df.loc[(df['InputID'] == aeroporto_origem) & (df['TargetID'] == aeroporto_destino[0])]
        
        if not linha.empty:  # Verifica se há dados para a combinação de aeroportos
            # Extrai os valores necessários da linha
            distancia = linha['Distância km'].values[0]
            tempo_comercial = linha['Tempo Médio Horas - Comercial'].values[0]
            tempo_carga = linha['Tempo Médio Horas - Cargueiro'].values[0]
            
            # Atualiza os dados do estado de destino
            dados_aeroportos[estado_destino] = [distancia, tempo_comercial, tempo_carga]

    # Prepara os dados para o aeroporto de origem atual
    dados_origem = {"Origem": aeroporto_origem}
    for estado_destino, valores in dados_aeroportos.items():
        dados_origem.update({
            f"{estado_destino} (Km)": valores[0],
            f"{estado_destino} (Hr - Comercial)": valores[1],
            f"{estado_destino} (Hr - Cargueiro)": valores[2],
        })
    
    # Adiciona os dados ao resultado
    result.append(dados_origem)

# Transforma o resultado em um DataFrame
df_result = pd.DataFrame(result)

df_result
# Out:
#                                                Origem  Alagoas (Km)  \
# 0               Aeroporto Internacional Pinto Martins           659
# 1     Aeroporto Internacional de Nursultan Nazarbayev         11988
# 2            Aeroporto Internacional de Xangai Pudong         16641
# 3           Aeroporto Internacional de Pequim Capital         15617
# 4          Aeroporto Internacional de Pyongyang Sunan         16188
# ..                                                ...           ...
# 59                               Aeroporto de Tallinn          9280
# 60                                 Aeroporto de Vágar          8260
# 61                             Aeroporto de Helsinque          9338
# 62                            Aeroporto de Copenhague          7479
# 63  Aeroporto Internacional Hartsfield-Jackson Atl...          6983
#
#    Alagoas (Hr - Comercial) Alagoas (Hr - Cargueiro)  Amapá (Km)  \
# 0             00:43 ~ 00:46            00:46 ~ 00:49        1458
# ...

# %%
# Ordena o DataFrame pela coluna "Distrito Federal (Km)"
df_result_sorted = df_result.reset_index(drop=True)

# Exporta o DataFrame ordenado para um arquivo CSV
df_result_sorted.to_csv('./csv_gerado/Tabela_Completa.csv', index=False)

df_result_sorted
# Out:
#                                                Origem  Alagoas (Km)  \
# 0               Aeroporto Internacional Pinto Martins           659
# 1     Aeroporto Internacional de Nursultan Nazarbayev         11988
# 2            Aeroporto Internacional de Xangai Pudong         16641
# 3           Aeroporto Internacional de Pequim Capital         15617
# 4          Aeroporto Internacional de Pyongyang Sunan         16188
# ..                                                ...           ...
# 59                               Aeroporto de Tallinn          9280
# 60                                 Aeroporto de Vágar          8260
# 61                             Aeroporto de Helsinque          9338
# 62                            Aeroporto de Copenhague          7479
# 63  Aeroporto Internacional Hartsfield-Jackson Atl...          6983
#
#    Alagoas (Hr - Comercial) Alagoas (Hr - Cargueiro)  Amapá (Km)  \
# 0             00:43 ~ 00:46            00:46 ~ 00:49        1458
# ...

# %% [markdown]
# # Dataset resumidos - por distância, horas de voo em avião comercial e de carga.

# %%
# Cria DataFrames separados para distâncias, emissões, tempos comerciais e tempos de carga
df_distancias = df_result.filter(["Origem"] + [f"{estado} (Km)" for estado in aeroportos_estado.keys()])
df_tempo_comercial = df_result.filter(["Origem"] + [f"{estado} (Hr - Comercial)" for estado in aeroportos_estado.keys()])
df_tempo_carga = df_result.filter(["Origem"] + [f"{estado} (Hr - Cargueiro)" for estado in aeroportos_estado.keys()])

# Exporta os DataFrames para arquivos CSV
df_distancias.to_csv('./csv_gerado/Tabela_Distâncias.csv', index=False)
df_tempo_comercial.to_csv('./csv_gerado/Tabela_Tempo_Comercial.csv', index=False)
df_tempo_carga.to_csv('./csv_gerado/Tabela_Tempo_Carga.csv', index=False)

# Exibe o DataFrame de distâncias
df_distancias
# Out:
#                                                Origem  Alagoas (Km)  \
# 0               Aeroporto Internacional Pinto Martins           659
# 1     Aeroporto Internacional de Nursultan Nazarbayev         11988
# 2            Aeroporto Internacional de Xangai Pudong         16641
# 3           Aeroporto Internacional de Pequim Capital         15617
# 4          Aeroporto Internacional de Pyongyang Sunan         16188
# ..                                                ...           ...
# 59                               Aeroporto de Tallinn          9280
# 60                                 Aeroporto de Vágar          8260
# 61                             Aeroporto de Helsinque          9338
# 62                            Aeroporto de Copenhague          7479
# 63  Aeroporto Internacional Hartsfield-Jackson Atl...          6983
#
#     Amapá (Km)  Amazonas (Km)  Bahia (Km) Bahia-Ilhéus (Km)  Ceará (Km)  \
# 0         1458           3082        1011              None           1
# ...

# %% [markdown]
# # Recebendo Voos_Nordeste

# %%
file_path = './csv_recebidos/Voos_Nordeste.csv'  # Arquivo com os nomes dos aeroportos

# Carrega os arquivos CSV em DataFrames
df_nordeste = pd.read_csv(file_path)  # DataFrame com as distâncias
df_nordeste
# Out:
#            UF do Produto                                   URF  Código NCM  \
# 0                Alagoas  Aeroporto Internacional de Guarulhos    84715010
# 1                  Bahia   Aeroporto Internacional de Salvador    84715020
# 2             Pernambuco  Aeroporto Internacional de Guarulhos    84715010
# 3    Rio Grande do Norte  Aeroporto Internacional de Guarulhos    84715010
# 4                Alagoas     Aeroporto Internacional do Recife    84715030
# ..                   ...                                   ...         ...
# 344             Maranhão  Aeroporto Internacional de Fortaleza    84715010
# 345           Pernambuco     Aeroporto Internacional do Recife    84715010
# 346                Bahia   Aeroporto Internacional de Salvador    84715010
# 347                Bahia   Aeroporto Internacional de Salvador    84715010
# 348                Ceará  Aeroporto Internacional de Fortaleza    84715010
#
# ...

# %% [markdown]
# # Grafo - Rota Original

# %%
aeroportos_nome = {
    "Aeroporto Internacional de Guarulhos": "SP-Guarulhos",
    "Aeroporto Internacional do Recife": "PE",
    "Aeroporto Internacional de Salvador": "BA",
    "Aeroporto Internacional de Natal": "RN",
    "Aeroporto Internacional de São Luís": "MA",
    "Aeroporto Internacional Pinto Martins": "CE",
    "Aeroporto Internacional de Nursultan Nazarbayev": "KAZ",
    "Aeroporto Internacional de Xangai Pudong": "CHN-Xangai",
    "Aeroporto Internacional de Pequim Capital": "CHN-Pequim",
    "Aeroporto Internacional de Pyongyang Sunan": "PRK",
    "Aeroporto Internacional de Incheon": "KOR",
    "Aeroporto Internacional Ninoy Aquino": "PHL",
    "Aeroporto Internacional de Hong Kong": "HKG",
    "Aeroporto Internacional Indira Gandhi": "IND-Delhi",
    "Aeroporto Internacional Soekarno-Hatta (Jacarta)": "IDN-Jakarta",
    "Aeroporto Internacional Ngurah Rai (Bali)": "IDN-Bali",
    "Aeroporto Internacional de Narita (Tóquio)": "JPN-Narita",
    "Aeroporto Internacional de Haneda (Tóquio)": "JPN-Haneda",
    "Aeroporto Internacional de Kansai (Osaka)": "JPN-Kansai",
    "Aeroporto Internacional de Wattay (Vientiane)": "LAO",
    "Aeroporto Internacional de Kuala Lumpur (Sepang)": "MYS",
    "Aeroporto Internacional de Penang (Penang)": "MYS-Penang",
    "Aeroporto Internacional de Malé": "MDV",
    "Aeroporto Internacional de Changi": "SGP",
    "Aeroporto Internacional de Suvarnabhumi": "THA-Bangkok",
    "Aeroporto Internacional Don Mueang": "THA-DonMueang",
    "Aeroporto Internacional de Taiwan Taoyuan": "TWN",
    "Aeroporto Internacional de Tan Son Nhat": "VNM-HoChiMinh",
    "Aeroporto Internacional de Noi Bai": "VNM-Hanoi",
    "Aeroporto de Frankfurt": "DEU-Frankfurt",
    "Aeroporto de Dublin": "IRL",
    "Aeroporto de Varsóvia Chopin": "POL",
    "Aeroporto de Oslo-Gardermoen": "NOR",
    "Aeroporto de Roma-Fiumicino": "ITA-Roma",
    "Aeroporto de Milão-Malpensa": "ITA-Milao",
    "Aeroporto de Praga": "CZE",
    "Aeroporto de Heathrow (Londres)": "GBR-Heathrow",
    "Aeroporto de Gatwick (Londres)": "GBR-Gatwick",
    "Aeroporto Internacional de Budapeste Ferenc Liszt": "HUN",
    "Aeroporto de Schiphol (Amsterdã)": "NLD",
    "Aeroporto Internacional de Boryspil (Kiev)": "UKR",
    "Aeroporto de Istambul": "TUR",
    "Aeroporto de Zurique": "CHE",
    "Aeroporto de Estocolmo-Arlanda": "SWE",
    "Aeroporto Nikola Tesla (Belgrado)": "SRB",
    "Aeroporto Internacional Sheremetyevo (Moscou)": "RUS-Moscou",
    "Aeroporto de Pulkovo (São Petersburgo)": "RUS-SPetersburgo",
    "Aeroporto Internacional Henri Coand? (Bucareste)": "ROU",
    "Aeroporto Humberto Delgado (Lisboa)": "PRT-Lisboa",
    "Aeroporto Francisco Sá Carneiro (Porto)": "PRT-Porto",
    "Aeroporto Internacional de Malta": "MLT",
    "Aeroporto de Luxemburgo": "LUX",
    "Aeroporto Internacional de Vilnius": "LTU",
    "Aeroporto Internacional de Riga": "LVA",
    "Aeroporto Internacional Madre Teresa (Tirana)": "ALB",
    "Aeroporto de Barcelona-El Prat (Espanha)": "ESP-Barcelona",
    "Aeroporto de Toulouse-Blagnac (França)": "FRA-Toulouse",
    "Aeroporto Internacional de Viena": "AUT",
    "Aeroporto de Bruxelas": "BEL",
    "Aeroporto de Sófia": "BGR",
    "Aeroporto de Bratislava": "SVK",
    "Aeroporto de Ljubljana Joe Pu?nik": "SVN",
    "Aeroporto Adolfo Suárez Madrid-Barajas": "ESP-Madrid",
    "Aeroporto de Barcelona-El Prat": "ESP-Barcelona",
    "Aeroporto de Tallinn": "EST",
    "Aeroporto de Vágar": "FRO",
    "Aeroporto de Helsinque": "FIN",
    "Aeroporto Internacional de Brasília": "DF",
    "Aeroporto Internacional de Várzea Grande": "MT",
    "Aeroporto Internacional de Belém": "PA",
    "Aeroporto Internacional de Tabatinga": "AM-Tabatinga",
    "Aeroporto Internacional de Manaus": "AM-Manaus",
    "Aeroporto Internacional de Macapá": "AP",
    "Aeroporto Internacional de Fortaleza": "CE",
    "Aeroporto Internacional de Maceió": "AL",
    "Aeroporto Internacional de Aracaju": "SE",
    "Aeroporto Internacional de Belo Horizonte": "MG",
    "Aeroporto Santos Dumont": "RJ-SantosDumont",
    "Aeroporto Internacional do Rio de Janeiro": "RJ-Galeão",
    "Aeroporto Internacional de Vitória": "ES",
    "Aeroporto Internacional de São José dos Campos": "SP-SJC",
    "Aeroporto Internacional de Viracopos": "SP-Viracopos",
    "Aeroporto Internacional de Curitiba": "PR",
    "Aeroporto Internacional de Florianópolis": "SC-Florianopolis",
    "Aeroporto Internacional de Navegantes": "SC-Navegantes",
    "Aeroporto Internacional de Porto Alegre": "RS",
    "Aeroporto Jorge Amado": "BA-Ilheus",
    "Aeroporto de Copenhague": "DNK",
    "Aeroporto Internacional Hartsfield-Jackson Atlanta": "USA-Atlanta",
    "Aeroporto de Teresina": "PI",
    "Aeroporto Internacional de João Pessoa": "PB"
}

# %%
aeroportos_exterior = {
    "Albânia": ["Aeroporto Internacional Madre Teresa (Tirana)"],
    "Alemanha": ["Aeroporto de Frankfurt"],
    "Andorra": [
        "Aeroporto de Barcelona-El Prat (Espanha)",
        "Aeroporto de Toulouse-Blagnac (França)"
    ],
    "Áustria": ["Aeroporto Internacional de Viena"],
    "Bélgica": ["Aeroporto de Bruxelas"],
    "Bulgária": ["Aeroporto de Sófia"],
    "Cazaquistão": ["Aeroporto Internacional de Nursultan Nazarbayev"],
    "China": [
        "Aeroporto Internacional de Xangai Pudong",
        "Aeroporto Internacional de Pequim Capital"
    ],
    "Coreia do Norte": ["Aeroporto Internacional de Pyongyang Sunan"],
    "Coreia do Sul": ["Aeroporto Internacional de Incheon"],
    "Dinamarca": ["Aeroporto de Copenhague"],
    "Eslováquia": ["Aeroporto de Bratislava"],
    "Eslovênia": ["Aeroporto de Ljubljana Joe Pu?nik"],
    "Espanha": [
        "Aeroporto Adolfo Suárez Madrid-Barajas",
        "Aeroporto de Barcelona-El Prat (Espanha)"
    ],
    "Estônia": ["Aeroporto de Tallinn"],
    "Estados Unidos"
    "Filipinas": ["Aeroporto Internacional Ninoy Aquino"],
    "Finlândia": ["Aeroporto de Helsinque"],
    "França": ["Aeroporto de Toulouse-Blagnac (França)"],
    "Hong Kong": ["Aeroporto Internacional de Hong Kong"],
    "Hungria": ["Aeroporto Internacional de Budapeste Ferenc Liszt"],
    "Ilhas Faroe": ["Aeroporto de Vágar"],
    "Índia": ["Aeroporto Internacional Indira Gandhi"],
    "Indonésia": [
        "Aeroporto Internacional Soekarno-Hatta (Jacarta)",
        "Aeroporto Internacional Ngurah Rai (Bali)"
    ],
    "Irlanda": ["Aeroporto de Dublin"],
    "Itália": [
        "Aeroporto de Roma-Fiumicino",
        "Aeroporto de Milão-Malpensa"
    ],
    "Japão": [
        "Aeroporto Internacional de Narita (Tóquio)",
        "Aeroporto Internacional de Haneda (Tóquio)",
        "Aeroporto Internacional de Kansai (Osaka)"
    ],
    "Laos": ["Aeroporto Internacional de Wattay (Vientiane)"],
    "Letônia": ["Aeroporto Internacional de Riga"],
    "Lituânia": ["Aeroporto Internacional de Vilnius"],
    "Luxemburgo": ["Aeroporto de Luxemburgo"],
    "Malásia": [
        "Aeroporto Internacional de Kuala Lumpur (Sepang)",
        "Aeroporto Internacional de Penang (Penang)"
    ],
    "Maldivas": ["Aeroporto Internacional de Malé"],
    "Malta": ["Aeroporto Internacional de Malta"],
    "Noruega": ["Aeroporto de Oslo-Gardermoen"],
    "Países Baixos (Holanda)": ["Aeroporto de Schiphol (Amsterdã)"],
    "Polônia": ["Aeroporto de Varsóvia Chopin"],
    "Portugal": [
        "Aeroporto Humberto Delgado (Lisboa)",
        "Aeroporto Francisco Sá Carneiro (Porto)"
    ],
    "Reino Unido": [
        "Aeroporto de Heathrow (Londres)",
        "Aeroporto de Gatwick (Londres)"
    ],
    "Tcheca, República": ["Aeroporto de Praga"],
    "Romênia": ["Aeroporto Internacional Henri Coand? (Bucareste)"],
    "Rússia": [
        "Aeroporto Internacional Sheremetyevo (Moscou)",
        "Aeroporto de Pulkovo (São Petersburgo)"
    ],
    "Sérvia": ["Aeroporto Nikola Tesla (Belgrado)"],
    "Singapura": ["Aeroporto Internacional de Changi"],
    "Suécia": ["Aeroporto de Estocolmo-Arlanda"],
    "Suíça": ["Aeroporto de Zurique"],
    "Tailândia": [
        "Aeroporto Internacional de Suvarnabhumi",
        "Aeroporto Internacional Don Mueang"
    ],
    "Taiwan (Formosa)": ["Aeroporto Internacional de Taiwan Taoyuan"],
    "Turquia": ["Aeroporto de Istambul"],
    "Ucrânia": ["Aeroporto Internacional de Boryspil (Kiev)"],
    "Vietnã": [
        "Aeroporto Internacional de Tan Son Nhat",
        "Aeroporto Internacional de Noi Bai"
    ]
}

# %%
aeroportos_nordeste = {"Alagoas": ["Aeroporto Internacional de Maceió"],
    "Bahia": ["Aeroporto Internacional de Salvador","Aeroporto Jorge Amado"],
    "Ceará": ["Aeroporto Internacional de Fortaleza"],
    "Maranhão": ["Aeroporto Internacional de São Luís"],
    "Paraíba": ["Aeroporto Internacional de João Pessoa"],
    "Pernambuco": ["Aeroporto Internacional do Recife"],
    "Piauí": ["Aeroporto de Teresina"],
    "Rio Grande do Norte": ["Aeroporto Internacional de Natal"],
    "Sergipe": ["Aeroporto Internacional de Aracaju"]}

# %%
# Dicionário para armazenar as rotas por estado
aeroportos_rotas = {}

# Preenche o dicionário com as rotas de cada estado
for i in aeroportos_nordeste.keys():
    df_aux = df_nordeste.loc[df_nordeste['UF do Produto'] == i]
    u = df_aux['Países'].unique()
    paises = u.tolist()
    aeroporto = []
    for j in paises:
        if j in aeroportos_exterior.keys():
            for k in aeroportos_exterior[j]:
                aeroporto.append(k)
    aeroportos_rotas[i] = aeroporto


aeroportos_rotas['Bahia']
# Out:
# ['Aeroporto de Frankfurt',
#  'Aeroporto Adolfo Suárez Madrid-Barajas',
#  'Aeroporto de Barcelona-El Prat (Espanha)',
#  'Aeroporto Internacional de Tan Son Nhat',
#  'Aeroporto Internacional de Noi Bai',
#  'Aeroporto Internacional de Kuala Lumpur (Sepang)',
#  'Aeroporto Internacional de Penang (Penang)',
#  'Aeroporto Internacional de Xangai Pudong',
#  'Aeroporto Internacional de Pequim Capital',
#  'Aeroporto de Praga',
#  'Aeroporto Internacional de Changi',
#  'Aeroporto de Estocolmo-Arlanda',
#  'Aeroporto Internacional de Budapeste Ferenc Liszt',
#  'Aeroporto Internacional de Viena',
#  'Aeroporto de Copenhague',
#  'Aeroporto de Roma-Fiumicino',
#  'Aeroporto de Milão-Malpensa',
#  'Aeroporto de Toulouse-Blagnac (França)',
#  'Aeroporto de Varsóvia Chopin',
#  'Aeroporto Internacional de Taiwan Taoyuan',
#  'Aeroporto de Heathrow (Londres)',
#  'Aeroporto de Gatwick (Londres)',
#  'Aeroporto de Bratislava',
#  'Aeroporto Internacional de Narita (Tóquio)',
# ...

# %%
dados = []  # Lista para armazenar os dados estruturados

for estado in aeroportos_nordeste.keys():
    df_aux = df_nordeste.loc[df_nordeste['UF do Produto'] == estado]
    
    for _, linha in df_aux.iterrows():
        aeroporto_nacional = linha['URF']
        origem = linha['Países']
        
        if origem in aeroportos_exterior.keys():
            for aeroporto_internacional in aeroportos_exterior[origem]:
                dados.append({
                    "Estado": estado,
                    "Aeroporto": aeroporto_nacional,
                    "Origem": aeroporto_internacional
                })

# Criar o DataFrame a partir da lista de dicionários
rotas_originais = pd.DataFrame(dados)
rotas_originais
# Out:
#                   Estado                             Aeroporto  \
# 0                Alagoas  Aeroporto Internacional de Guarulhos
# 1                Alagoas  Aeroporto Internacional de Guarulhos
# 2                Alagoas     Aeroporto Internacional do Recife
# 3                Alagoas  Aeroporto Internacional de Guarulhos
# 4                Alagoas  Aeroporto Internacional de Guarulhos
# ..                   ...                                   ...
# 372  Rio Grande do Norte  Aeroporto Internacional de Fortaleza
# 373  Rio Grande do Norte     Aeroporto Internacional do Recife
# 374  Rio Grande do Norte  Aeroporto Internacional de Guarulhos
# 375              Sergipe  Aeroporto Internacional de Guarulhos
# 376              Sergipe  Aeroporto Internacional de Guarulhos
#
#                                         Origem
# 0     Aeroporto Internacional de Xangai Pudong
# 1    Aeroporto Internacional de Pequim Capital
# 2                           Aeroporto de Praga
# ...

# %%
def best_route(alvo,regional):
    for i in regional:
        aux = df[(df['InputID'] == alvo) & (df['TargetID'] == i)]['Distância km'].values[0]
        min = 0
        if min == 0 or aux < min:
            melhor = i
            min = aux
    
    return melhor

def create_table(tabela, edges,internacional,regional,estado,df, eficiencia, velocidade):
    for i in edges:
        aux = {'Destino' : estado}
        if i[0] in internacional:
            if i[1] in regional:
                distancia = df[(df['InputID'] == i[0]) & (df['TargetID'] == i[1])]['Distância km'].values[0]
                tempo = distancia / velocidade
                emissao = round((((3.15 * (eficiencia * distancia * tempo)) / velocidade) / 1000),2)
                aux.update({
                    'Origem' : i[0],
                    'Intermerdiario' : '*',
                    'Final' : i[1],
                    'Distancia' : distancia,
                    'Emissão de CO2' : emissao})
                tabela.append(aux) 
            else:
                target = best_route(i[1],regional)
                distancia = df[(df['InputID'] == i[0]) & (df['TargetID'] == i[1])]['Distância km'].values[0] + df[(df['InputID'] == target) & (df['TargetID'] == i[1])]['Distância km'].values[0]
                tempo = distancia / velocidade
                emissao = round((((3.15 * (eficiencia * distancia * tempo)) / velocidade) / 1000),2)
                aux.update({
                    'Origem' : i[0],
                    'Intermerdiario' : i[1],
                    'Final' : target,
                    'Distancia' : distancia,
                    'Emissão de CO2' : emissao})
                tabela.append(aux) 
    return tabela

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Função para calcular distâncias entre aeroportos
def achar_distancias(lista_nacionais, lista_interesse, df):
    df_filtrado = df[
        (df['InputID'].isin(lista_nacionais)) &
        (df['TargetID'].isin(lista_interesse))
    ]
    distancias = {}
    for nacional in lista_nacionais:
        distancias[nacional] = {}
        for interesse in lista_interesse:
            distancia = df_filtrado[
                (df_filtrado['InputID'] == nacional) & 
                (df_filtrado['TargetID'] == interesse)
            ]['Distância km']
            distancias[nacional][interesse] = distancia.values[0] if not distancia.empty else 0
    return distancias

# Função para carregar o grafo a partir do DataFrame
def load_graph_from_df(df, rotas, source_airports, hub_airports, local_airports):
    G = nx.DiGraph()

    dist_origem_hub = achar_distancias(source_airports, hub_airports, df)
    dist_hub_destino = achar_distancias(hub_airports, local_airports, df)

    for origem in source_airports:
        for hub in hub_airports:
            for destino in local_airports:
                d1 = dist_origem_hub.get(origem, {}).get(hub, 0)
                d2 = dist_hub_destino.get(hub, {}).get(destino, 0)

                if d1 > 0 and d2 > 0:
                    # Adiciona aresta origem -> hub
                    if not G.has_edge(origem, hub):
                        tempo1 = d1 / 875
                        w1 = ((3.15 * (4412.5 * d1 * tempo1)) / 875) / 1000
                        G.add_edge(origem, hub, weight=w1)

                    # Adiciona aresta hub -> destino
                    if not G.has_edge(hub, destino):
                        tempo2 = d2 / 875
                        w2 = ((3.15 * (4412.5 * d2 * tempo2)) / 875) / 1000
                        G.add_edge(hub, destino, weight=w2)

    return G

# Função para destacar as rotas ideais
def highlight_routes(G, international_airports, national_airports, regional_airports):
    ideal_path_edges = set()
    for intl_airport in international_airports:
        if intl_airport not in G:
            continue
        try:
            min_total_weight = float('inf')
            best_path_to_regional = None
            for regional_airport in regional_airports:
                if regional_airport not in G:
                    continue
                for national_airport in national_airports:
                    if national_airport not in G:
                        continue
                    try:
                        path_to_national = nx.shortest_path(G, source=intl_airport, target=national_airport, weight='weight')
                        weight_to_national = nx.path_weight(G, path_to_national, weight='weight')
                        path_to_regional = nx.shortest_path(G, source=national_airport, target=regional_airport, weight='weight')
                        weight_to_regional = nx.path_weight(G, path_to_regional, weight='weight')
                        total_weight = weight_to_national + weight_to_regional
                        if total_weight < min_total_weight:
                            min_total_weight = total_weight
                            best_path_to_regional = path_to_national + path_to_regional[1:]
                    except nx.NetworkXNoPath:
                        continue
            if best_path_to_regional:
                for i in range(len(best_path_to_regional) - 1):
                    edge = (best_path_to_regional[i], best_path_to_regional[i + 1])
                    ideal_path_edges.add(edge)
        except nx.NetworkXNoPath:
            continue
    return list(ideal_path_edges)

def plot_clean_graph(G, ideal_path_edges, interest_airports, local_airports, title_suffix, save_path):
    pos = nx.circular_layout(G)
    plt.figure(figsize=(12, 10))
    
    # Define as cores dos nós
    node_colors = {
        'Destino': 'orange',
        'Nacional': 'lightgreen',
        'Internacional': 'lightblue'
    }
    
    node_color_list = [
        node_colors['Destino'] if node in local_airports else 
        node_colors['Nacional'] if node in interest_airports else 
        node_colors['Internacional']
        for node in G.nodes
    ]
    
    node_labels = {node: aeroportos_nome[node] for node in G.nodes}
    
    nx.draw_networkx_nodes(G, pos, node_color=node_color_list, node_size=800, alpha=0.9)
    
    regular_edges = [edge for edge in G.edges if edge not in ideal_path_edges]
    nx.draw_networkx_edges(G, pos, edgelist=regular_edges, edge_color='gray', alpha=0.5, width=1)
    nx.draw_networkx_edges(G, pos, edgelist=ideal_path_edges, edge_color='red', width=2.5)
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=9, font_color='black')
    
    edge_labels = nx.get_edge_attributes(G, 'weight')
    highlighted_labels = {edge: f"{round(weight, 2)}" for edge, weight in edge_labels.items() if edge in ideal_path_edges}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=highlighted_labels, font_size=8, font_color='red')
    
    plt.title(f'{title_suffix}')
    plt.axis('off')
    
    # Adiciona legenda manualmente
    legend_labels = {
        "Destino": 'orange',
        "Nacional": 'lightgreen',
        "Internacional": 'lightblue'
    }
    
    for label, color in legend_labels.items():
        plt.scatter([], [], c=color, label=label, s=100, alpha=0.9, edgecolors='k')
    
    plt.legend(loc='upper right', title="Legenda", fontsize=10, title_fontsize=11)
    
    plt.savefig(save_path)  # Salva o gráfico
    plt.close()  # Fecha a figura para liberar memória


tabela_rotas_comercial = []

# Loop para processar aeroportos em lotes
for estado in aeroportos_nordeste.keys():
    batch_size = 30
    aeroportos_origem = aeroportos_rotas[estado]
    aeroportos_destino = aeroportos_estado[estado]
    
    for j in range(0, len(aeroportos_origem), batch_size):
        subset_origem = aeroportos_origem[j:j + batch_size]
        
        # Filtra as rotas apenas para essas origens e para o estado atual
        rotas = rotas_originais[
            (rotas_originais['Estado'] == estado) & 
            (rotas_originais['Origem'].isin(subset_origem))
        ]
        
        # Extrai os aeroportos intermediários (hubs nacionais)
        aeroportos_intermediarios = list(rotas['Aeroporto'].unique())

        # ⚠️ AQUI usamos sua nova função load_graph_from_df
        G = load_graph_from_df(df, rotas, subset_origem, aeroportos_intermediarios, aeroportos_destino)

        # Calcula as rotas ideais (menor peso passando por hubs)
        ideal_path_edges = highlight_routes(G, subset_origem, aeroportos_intermediarios, aeroportos_destino)

        # Cria/atualiza a tabela de rotas ideais
        tabela_rotas_comercial = create_table(tabela_rotas_comercial, ideal_path_edges, subset_origem, aeroportos_destino, estado, df, 4412.5, 875)
        
        # Gera e salva o gráfico do grafo com destaque nas rotas ideais
        save_path = f"grafos_original_nordeste_co/{estado}_{j//batch_size + 1}.png"
        plot_clean_graph(G, ideal_path_edges, aeroportos_intermediarios, aeroportos_destino, title_suffix=f"{estado}", save_path=save_path)

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Função para calcular distâncias entre aeroportos
def achar_distancias(lista_nacionais, lista_interesse, df):
    df_filtrado = df[
        (df['InputID'].isin(lista_nacionais)) &
        (df['TargetID'].isin(lista_interesse))
    ]
    distancias = {}
    for nacional in lista_nacionais:
        distancias[nacional] = {}
        for interesse in lista_interesse:
            distancia = df_filtrado[
                (df_filtrado['InputID'] == nacional) & 
                (df_filtrado['TargetID'] == interesse)
            ]['Distância km']
            distancias[nacional][interesse] = distancia.values[0] if not distancia.empty else 0
    return distancias

# Função para carregar o grafo a partir do DataFrame
def load_graph_from_df(df, rotas, source_airports, interest_airports, local_airports):
    G = nx.DiGraph()

    # Calcula distâncias origem → intermediário (nacional)
    dist_origem_interesse = achar_distancias(source_airports, interest_airports, df)
    # Calcula distâncias intermediário → destino (local)
    dist_interesse_destino = achar_distancias(interest_airports, local_airports, df)

    for origem in source_airports:
        for intermediario in interest_airports:
            for destino in local_airports:
                d1 = dist_origem_interesse.get(origem, {}).get(intermediario, 0)
                d2 = dist_interesse_destino.get(intermediario, {}).get(destino, 0)

                if d1 > 0 and d2 > 0:
                    # Adiciona aresta origem → intermediário
                    if not G.has_edge(origem, intermediario):
                        tempo1 = d1 / 825
                        w1 = ((3.15 * (4412.5 * d1 * tempo1)) / 825) / 1000
                        G.add_edge(origem, intermediario, weight=w1)

                    # Adiciona aresta intermediário → destino
                    if not G.has_edge(intermediario, destino):
                        tempo2 = d2 / 825
                        w2 = ((3.15 * (4412.5 * d2 * tempo2)) / 825) / 1000
                        G.add_edge(intermediario, destino, weight=w2)

    return G

# Função para destacar as rotas ideais
def highlight_routes(G, international_airports, national_airports, regional_airports):
    ideal_path_edges = set()
    for intl_airport in international_airports:
        if intl_airport not in G:
            continue
        try:
            min_total_weight = float('inf')
            best_path_to_regional = None
            for regional_airport in regional_airports:
                if regional_airport not in G:
                    continue
                for national_airport in national_airports:
                    if national_airport not in G:
                        continue
                    try:
                        path_to_national = nx.shortest_path(G, source=intl_airport, target=national_airport, weight='weight')
                        weight_to_national = nx.path_weight(G, path_to_national, weight='weight')
                        path_to_regional = nx.shortest_path(G, source=national_airport, target=regional_airport, weight='weight')
                        weight_to_regional = nx.path_weight(G, path_to_regional, weight='weight')
                        total_weight = weight_to_national + weight_to_regional
                        if total_weight < min_total_weight:
                            min_total_weight = total_weight
                            best_path_to_regional = path_to_national + path_to_regional[1:]
                    except nx.NetworkXNoPath:
                        continue
            if best_path_to_regional:
                for i in range(len(best_path_to_regional) - 1):
                    edge = (best_path_to_regional[i], best_path_to_regional[i + 1])
                    ideal_path_edges.add(edge)
        except nx.NetworkXNoPath:
            continue
    return list(ideal_path_edges)


def plot_clean_graph(G, ideal_path_edges, interest_airports, local_airports, title_suffix, save_path):
    pos = nx.circular_layout(G)
    plt.figure(figsize=(12, 10))
    
    # Define as cores dos nós
    node_colors = {
        'Destino': 'orange',
        'Nacional': 'lightgreen',
        'Internacional': 'lightblue'
    }
    
    node_color_list = [
        node_colors['Destino'] if node in local_airports else 
        node_colors['Nacional'] if node in interest_airports else 
        node_colors['Internacional']
        for node in G.nodes
    ]
    
    node_labels = {node: aeroportos_nome[node] for node in G.nodes}
    
    nx.draw_networkx_nodes(G, pos, node_color=node_color_list, node_size=800, alpha=0.9)
    
    regular_edges = [edge for edge in G.edges if edge not in ideal_path_edges]
    nx.draw_networkx_edges(G, pos, edgelist=regular_edges, edge_color='gray', alpha=0.5, width=1)
    nx.draw_networkx_edges(G, pos, edgelist=ideal_path_edges, edge_color='red', width=2.5)
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=9, font_color='black')
    
    edge_labels = nx.get_edge_attributes(G, 'weight')
    highlighted_labels = {edge: f"{round(weight,2)}" for edge, weight in edge_labels.items() if edge in ideal_path_edges}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=highlighted_labels, font_size=8, font_color='red')
    
    plt.title(f'{title_suffix}')
    plt.axis('off')
    
    # Adiciona legenda manualmente
    legend_labels = {
        "Destino": 'orange',
        "Nacional": 'lightgreen',
        "Internacional": 'lightblue'
    }
    
    for label, color in legend_labels.items():
        plt.scatter([], [], c=color, label=label, s=100, alpha=0.9, edgecolors='k')
    
    plt.legend(loc='upper right', title="Legenda", fontsize=10, title_fontsize=11)
    
    plt.savefig(save_path)  # Salva o gráfico
    plt.close()  # Fecha a figura para liberar memória
    
tabela_rotas_carga = []
# Loop para processar aeroportos em lotes
for i in aeroportos_nordeste.keys():
    batch_size = 30
    for j in range(0, len(aeroportos_rotas[i]), batch_size):
        subset_origem = aeroportos_rotas[i][j:j + batch_size]
        rotas = rotas_originais[
            (rotas_originais['Estado'] == i) & 
            (rotas_originais['Origem'].isin(subset_origem))
        ]
        aeroportos_intermediarios = []
        for _, linha in rotas.iterrows():
            aeroportos_intermediarios.append(linha['Aeroporto'])

        G = load_graph_from_df(df, rotas, subset_origem, aeroportos_intermediarios, aeroportos_estado[i])
        ideal_path_edges = highlight_routes(G, subset_origem, aeroportos_intermediarios, aeroportos_estado[i])        
        tabela_rotas_carga = create_table(tabela_rotas_carga,ideal_path_edges,subset_origem, aeroportos_estado[i],i,df,5625,825)
        save_path = f"grafos_original_nordeste_ca/{i}_{j//batch_size + 1}.png"
        plot_clean_graph(G, ideal_path_edges, aeroportos_intermediarios, aeroportos_estado[i], title_suffix=f"{i}", save_path=save_path)

# %%
tabela_rotas_comercial = pd.DataFrame(tabela_rotas_comercial)
tabela_rotas_carga = pd.DataFrame(tabela_rotas_carga)

# Exporta o DataFrame ordenado para um arquivo CSV
tabela_rotas_comercial.to_csv('./csv_gerado/Tabela_Original_Nordeste_CO.csv', index=False)
tabela_rotas_carga.to_csv('./csv_gerado/Tabela_Original_Nordeste_CA.csv', index=False)

tabela_rotas_comercial
# Out:
#                  Destino                                     Origem  \
# 0                Alagoas                     Aeroporto de Frankfurt
# 1                Alagoas  Aeroporto Internacional de Pequim Capital
# 2                Alagoas   Aeroporto Internacional de Xangai Pudong
# 3                Alagoas                         Aeroporto de Praga
# 4                  Bahia    Aeroporto Internacional de Suvarnabhumi
# ..                   ...                                        ...
# 99   Rio Grande do Norte  Aeroporto Internacional de Pequim Capital
# 100  Rio Grande do Norte                     Aeroporto de Frankfurt
# 101  Rio Grande do Norte                Aeroporto de Roma-Fiumicino
# 102              Sergipe  Aeroporto Internacional de Pequim Capital
# 103              Sergipe   Aeroporto Internacional de Xangai Pudong
#
#                            Intermerdiario  \
# 0       Aeroporto Internacional do Recife
# 1       Aeroporto Internacional do Recife
# ...

# %% [markdown]
# # Grafo - Rota Proposta

# %%
aeroportos_Hub = ["Aeroporto Internacional de Maceió",
                  "Aeroporto Internacional de Salvador",
                  "Aeroporto Internacional de Fortaleza",
                  "Aeroporto Internacional de São Luís",
                  "Aeroporto Internacional do Recife",
                  "Aeroporto Internacional de Natal",
                  "Aeroporto Internacional de Aracaju",
                  "Aeroporto Internacional de João Pessoa",
                  "Aeroporto de Teresina"]

# %%
dados = []  # Lista para armazenar os dados estruturados

for estado in aeroportos_nordeste.keys():
    df_aux = df_nordeste.loc[df_nordeste['UF do Produto'] == estado]
    
    for _, linha in df_aux.iterrows():
        for i in aeroportos_Hub:
            aeroporto_nacional = i
            origem = linha['Países']
            if origem in aeroportos_exterior.keys():
                for aeroporto_internacional in aeroportos_exterior[origem]:
                    dados.append({
                        "Estado": estado,
                        "Aeroporto": aeroporto_nacional,
                        "Origem": aeroporto_internacional
                    })

# Criar o DataFrame a partir da lista de dicionários
rotas_originais = pd.DataFrame(dados)
rotas_originais
# Out:
#        Estado                               Aeroporto  \
# 0     Alagoas       Aeroporto Internacional de Maceió
# 1     Alagoas       Aeroporto Internacional de Maceió
# 2     Alagoas     Aeroporto Internacional de Salvador
# 3     Alagoas     Aeroporto Internacional de Salvador
# 4     Alagoas    Aeroporto Internacional de Fortaleza
# ...       ...                                     ...
# 3388  Sergipe      Aeroporto Internacional de Aracaju
# 3389  Sergipe  Aeroporto Internacional de João Pessoa
# 3390  Sergipe  Aeroporto Internacional de João Pessoa
# 3391  Sergipe                   Aeroporto de Teresina
# 3392  Sergipe                   Aeroporto de Teresina
#
#                                          Origem
# 0      Aeroporto Internacional de Xangai Pudong
# 1     Aeroporto Internacional de Pequim Capital
# 2      Aeroporto Internacional de Xangai Pudong
# 3     Aeroporto Internacional de Pequim Capital
# 4      Aeroporto Internacional de Xangai Pudong
# ...

# %%
# -----------------------------
# Função para calcular distâncias entre aeroportos
def achar_distancias(lista_origem, lista_destino, df):
    df_filtrado = df[
        (df['InputID'].isin(lista_origem)) &
        (df['TargetID'].isin(lista_destino))
    ]
    distancias = {}
    for origem in lista_origem:
        distancias[origem] = {}
        for destino in lista_destino:
            distancia = df_filtrado[
                (df_filtrado['InputID'] == origem) & 
                (df_filtrado['TargetID'] == destino)
            ]['Distância km']
            distancias[origem][destino] = distancia.values[0] if not distancia.empty else 0
    return distancias

# -----------------------------
# Carrega grafo com origem -> hub -> destino
def load_graph_from_df(df, rotas, source_airports, hub_airports, local_airports):
    G = nx.DiGraph()

    dist_origem_hub = achar_distancias(source_airports, hub_airports, df)
    dist_hub_destino = achar_distancias(hub_airports, local_airports, df)

    for origem in source_airports:
        for hub in hub_airports:
            for destino in local_airports:
                d1 = dist_origem_hub.get(origem, {}).get(hub, 0)
                d2 = dist_hub_destino.get(hub, {}).get(destino, 0)

                if d1 > 0 and d2 > 0:
                    # Adiciona aresta origem -> hub
                    if not G.has_edge(origem, hub):
                        tempo1 = d1 / 875
                        w1 = ((3.15 * (4412.5 * d1 * tempo1)) / 875) / 1000
                        G.add_edge(origem, hub, weight=w1)

                    # Adiciona aresta hub -> destino
                    if not G.has_edge(hub, destino):
                        tempo2 = d2 / 875
                        w2 = ((3.15 * (4412.5 * d2 * tempo2)) / 875) / 1000
                        G.add_edge(hub, destino, weight=w2)

    return G

# -----------------------------
# Encontra caminhos ideais passando por hubs
def highlight_routes(G, international_airports, hub_airports, regional_airports):
    ideal_path_edges = set()
    for intl_airport in international_airports:
        if intl_airport not in G:
            continue
        try:
            min_total_weight = float('inf')
            best_path = None
            for hub in hub_airports:
                if hub not in G:
                    continue
                for destino in regional_airports:
                    if destino not in G:
                        continue
                    try:
                        path1 = nx.shortest_path(G, source=intl_airport, target=hub, weight='weight')
                        w1 = nx.path_weight(G, path1, weight='weight')
                        path2 = nx.shortest_path(G, source=hub, target=destino, weight='weight')
                        w2 = nx.path_weight(G, path2, weight='weight')
                        total_weight = w1 + w2
                        if total_weight < min_total_weight:
                            min_total_weight = total_weight
                            best_path = path1 + path2[1:]
                    except nx.NetworkXNoPath:
                        continue
            if best_path:
                for i in range(len(best_path) - 1):
                    ideal_path_edges.add((best_path[i], best_path[i + 1]))
        except nx.NetworkXNoPath:
            continue
    return list(ideal_path_edges)

# -----------------------------
# Função para desenhar e salvar o grafo
def plot_clean_graph(G, ideal_path_edges, hub_airports, local_airports, title_suffix, save_path):
    pos = nx.circular_layout(G)
    plt.figure(figsize=(12, 10))
    
    node_colors = {
        'Destino': 'orange',
        'Nacional': 'lightgreen',
        'Internacional': 'lightblue'
    }

    node_color_list = [
        node_colors['Destino'] if node in local_airports else 
        node_colors['Nacional'] if node in hub_airports else 
        node_colors['Internacional']
        for node in G.nodes
    ]
    
    node_labels = {node: aeroportos_nome[node] for node in G.nodes}
    
    nx.draw_networkx_nodes(G, pos, node_color=node_color_list, node_size=800, alpha=0.9)
    regular_edges = [edge for edge in G.edges if edge not in ideal_path_edges]
    nx.draw_networkx_edges(G, pos, edgelist=regular_edges, edge_color='gray', alpha=0.5, width=1)
    nx.draw_networkx_edges(G, pos, edgelist=ideal_path_edges, edge_color='red', width=2.5)
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=9, font_color='black')

    edge_labels = nx.get_edge_attributes(G, 'weight')
    highlighted_labels = {edge: f"{round(weight, 2)}" for edge, weight in edge_labels.items() if edge in ideal_path_edges}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=highlighted_labels, font_size=8, font_color='red')

    plt.title(f'{title_suffix}')
    plt.axis('off')
    for label, color in node_colors.items():
        plt.scatter([], [], c=color, label=label, s=100, alpha=0.9, edgecolors='k')
    plt.legend(loc='upper right', title="Legenda", fontsize=10, title_fontsize=11)

    plt.savefig(save_path)
    plt.close()

# -----------------------------
# Loop principal com rotas via Hubs
tabela_hub_comercial = []

for estado in aeroportos_nordeste.keys():
    batch_size = 30
    for j in range(0, len(aeroportos_rotas[estado]), batch_size):
        subset_origem = aeroportos_rotas[estado][j:j + batch_size]
        aeroportos_destino = aeroportos_estado[estado]

        G = load_graph_from_df(df, None, subset_origem, aeroportos_Hub, aeroportos_destino)
        ideal_path_edges = highlight_routes(G, subset_origem, aeroportos_Hub, aeroportos_destino)

        tabela_hub_comercial = create_table(tabela_hub_comercial, ideal_path_edges, subset_origem, aeroportos_destino, estado, df, 4412.5, 875)

        save_path = f"grafos_hub_nordeste_co/{estado}_{j//batch_size + 1}.png"
        plot_clean_graph(G, ideal_path_edges, aeroportos_Hub, aeroportos_destino, title_suffix=f"{estado}", save_path=save_path)

# %%
# -----------------------------
# Função para calcular distâncias entre aeroportos
def achar_distancias(lista_origem, lista_destino, df):
    df_filtrado = df[
        (df['InputID'].isin(lista_origem)) &
        (df['TargetID'].isin(lista_destino))
    ]
    distancias = {}
    for origem in lista_origem:
        distancias[origem] = {}
        for destino in lista_destino:
            distancia = df_filtrado[
                (df_filtrado['InputID'] == origem) & 
                (df_filtrado['TargetID'] == destino)
            ]['Distância km']
            distancias[origem][destino] = distancia.values[0] if not distancia.empty else 0
    return distancias

# -----------------------------
# Carrega grafo com origem -> hub -> destino
def load_graph_from_df(df, rotas, source_airports, hub_airports, local_airports):
    G = nx.DiGraph()

    dist_origem_hub = achar_distancias(source_airports, hub_airports, df)
    dist_hub_destino = achar_distancias(hub_airports, local_airports, df)

    for origem in source_airports:
        for hub in hub_airports:
            for destino in local_airports:
                d1 = dist_origem_hub.get(origem, {}).get(hub, 0)
                d2 = dist_hub_destino.get(hub, {}).get(destino, 0)

                if d1 > 0 and d2 > 0:
                    # Adiciona aresta origem -> hub
                    if not G.has_edge(origem, hub):
                        tempo1 = d1 / 825
                        w1 = ((3.15 * (5625 * d1 * tempo1)) / 825) / 1000
                        G.add_edge(origem, hub, weight=w1)

                    # Adiciona aresta hub -> destino
                    if not G.has_edge(hub, destino):
                        tempo2 = d2 / 825
                        w2 = ((3.15 * (5625 * d2 * tempo2)) / 825) / 1000
                        G.add_edge(hub, destino, weight=w2)

    return G

# -----------------------------
# Encontra caminhos ideais passando por hubs
def highlight_routes(G, international_airports, hub_airports, regional_airports):
    ideal_path_edges = set()
    for intl_airport in international_airports:
        if intl_airport not in G:
            continue
        try:
            min_total_weight = float('inf')
            best_path = None
            for hub in hub_airports:
                if hub not in G:
                    continue
                for destino in regional_airports:
                    if destino not in G:
                        continue
                    try:
                        path1 = nx.shortest_path(G, source=intl_airport, target=hub, weight='weight')
                        w1 = nx.path_weight(G, path1, weight='weight')
                        path2 = nx.shortest_path(G, source=hub, target=destino, weight='weight')
                        w2 = nx.path_weight(G, path2, weight='weight')
                        total_weight = w1 + w2
                        if total_weight < min_total_weight:
                            min_total_weight = total_weight
                            best_path = path1 + path2[1:]
                    except nx.NetworkXNoPath:
                        continue
            if best_path:
                for i in range(len(best_path) - 1):
                    ideal_path_edges.add((best_path[i], best_path[i + 1]))
        except nx.NetworkXNoPath:
            continue
    return list(ideal_path_edges)

# -----------------------------
# Função para desenhar e salvar o grafo
def plot_clean_graph(G, ideal_path_edges, hub_airports, local_airports, title_suffix, save_path):
    pos = nx.circular_layout(G)
    plt.figure(figsize=(12, 10))
    
    node_colors = {
        'Destino': 'orange',
        'Nacional': 'lightgreen',
        'Internacional': 'lightblue'
    }

    node_color_list = [
        node_colors['Destino'] if node in local_airports else 
        node_colors['Nacional'] if node in hub_airports else 
        node_colors['Internacional']
        for node in G.nodes
    ]
    
    node_labels = {node: aeroportos_nome[node] for node in G.nodes}
    
    nx.draw_networkx_nodes(G, pos, node_color=node_color_list, node_size=800, alpha=0.9)
    regular_edges = [edge for edge in G.edges if edge not in ideal_path_edges]
    nx.draw_networkx_edges(G, pos, edgelist=regular_edges, edge_color='gray', alpha=0.5, width=1)
    nx.draw_networkx_edges(G, pos, edgelist=ideal_path_edges, edge_color='red', width=2.5)
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=9, font_color='black')

    edge_labels = nx.get_edge_attributes(G, 'weight')
    highlighted_labels = {edge: f"{round(weight, 2)}" for edge, weight in edge_labels.items() if edge in ideal_path_edges}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=highlighted_labels, font_size=8, font_color='red')

    plt.title(f'{title_suffix}')
    plt.axis('off')
    for label, color in node_colors.items():
        plt.scatter([], [], c=color, label=label, s=100, alpha=0.9, edgecolors='k')
    plt.legend(loc='upper right', title="Legenda", fontsize=10, title_fontsize=11)

    plt.savefig(save_path)
    plt.close()

# -----------------------------
# Loop principal com rotas via Hubs
tabela_hub_carga = []

for estado in aeroportos_nordeste.keys():
    batch_size = 30
    for j in range(0, len(aeroportos_rotas[estado]), batch_size):
        subset_origem = aeroportos_rotas[estado][j:j + batch_size]
        aeroportos_destino = aeroportos_estado[estado]

        G = load_graph_from_df(df, None, subset_origem, aeroportos_Hub, aeroportos_destino)
        ideal_path_edges = highlight_routes(G, subset_origem, aeroportos_Hub, aeroportos_destino)

        tabela_hub_carga = create_table(tabela_hub_carga, ideal_path_edges, subset_origem, aeroportos_destino, estado, df, 5625,825)

        save_path = f"grafos_hub_nordeste_ca/{estado}_{j//batch_size + 1}.png"
        plot_clean_graph(G, ideal_path_edges, aeroportos_Hub, aeroportos_destino, title_suffix=f"{estado}", save_path=save_path)

# %%
tabela_hub_comercial = pd.DataFrame(tabela_hub_comercial)
tabela_hub_carga = pd.DataFrame(tabela_hub_carga)

# Exporta o DataFrame ordenado para um arquivo CSV
tabela_hub_comercial.to_csv('./csv_gerado/Tabela_Hub_Nordeste_CO.csv', index=False)
tabela_hub_carga.to_csv('./csv_gerado/Tabela_Hub_Nordeste_CA.csv', index=False)

tabela_hub_comercial
# Out:
#                  Destino                                     Origem  \
# 0                Alagoas   Aeroporto Internacional de Xangai Pudong
# 1                Alagoas                         Aeroporto de Praga
# 2                Alagoas  Aeroporto Internacional de Pequim Capital
# 3                Alagoas                     Aeroporto de Frankfurt
# 4                  Bahia  Aeroporto Internacional de Taiwan Taoyuan
# ..                   ...                                        ...
# 99   Rio Grande do Norte  Aeroporto Internacional de Pequim Capital
# 100  Rio Grande do Norte                     Aeroporto de Frankfurt
# 101  Rio Grande do Norte                Aeroporto de Roma-Fiumicino
# 102              Sergipe  Aeroporto Internacional de Pequim Capital
# 103              Sergipe   Aeroporto Internacional de Xangai Pudong
#
#                            Intermerdiario  \
# 0        Aeroporto Internacional de Natal
# 1        Aeroporto Internacional de Natal
# ...

# %% [markdown]
# # Tabela Comparativa

# %%
import pandas as pd

# Convertendo listas de dicionários em DataFrames
tabela_rotas_carga = pd.DataFrame(tabela_rotas_carga)
tabela_hub_carga = pd.DataFrame(tabela_hub_carga)
tabela_rotas_comercial = pd.DataFrame(tabela_rotas_comercial)
tabela_hub_comercial = pd.DataFrame(tabela_hub_comercial)

# Função para criar a tabela comparativa
def criar_tabela_comparativa(tabela_rotas, tabela_hub, tipo):
    # Renomeando colunas da tabela de rotas para padronizar
    tabela_comparativa = tabela_rotas[['Destino', 'Origem', 'Distancia', 'Emissão de CO2']].copy()
    tabela_comparativa.rename(columns={
        'Destino': 'Estado',
        'Distancia': f'Distância original {tipo}',
        'Emissão de CO2': f'Emissão original {tipo}'
    }, inplace=True)

    # Agrupando a tabela_hub por 'Destino' (estado) e 'Origem' para calcular as médias
    tabela_hub_agrupada = tabela_hub.groupby(['Destino', 'Origem'], as_index=False).agg({
        'Distancia': 'mean',
        'Emissão de CO2': 'mean'
    })

    # Mesclando as informações agregadas na tabela comparativa
    tabela_comparativa = tabela_comparativa.merge(
        tabela_hub_agrupada.rename(columns={
            'Destino': 'Estado',
            'Distancia': f'Distância hub {tipo}',
            'Emissão de CO2': f'Emissão hub {tipo}'
        }),
        on=['Estado', 'Origem'],
        how='left'
    )

    return tabela_comparativa

# Criando as tabelas comparativas separadas
tabela_comparativa_carga = criar_tabela_comparativa(tabela_rotas_carga, tabela_hub_carga, "carga")
tabela_comparativa_comercial = criar_tabela_comparativa(tabela_rotas_comercial, tabela_hub_comercial, "comercial")

# Unindo as tabelas de carga e comercial
tabela_comparativa = tabela_comparativa_carga.merge(
    tabela_comparativa_comercial,
    on=['Origem', 'Estado'],
    how='outer'
)

# Convertendo colunas numéricas para inteiros (preenchendo NaN com 0)
colunas_numericas = [
    'Distância hub carga', 'Distância original carga', 'Distância hub comercial', 'Distância original comercial',
    'Emissão hub carga', 'Emissão original carga', 'Emissão hub comercial', 'Emissão original comercial'
]
for coluna in colunas_numericas:
    tabela_comparativa[coluna] = tabela_comparativa[coluna].fillna(0).astype(int)

# Salvando a tabela comparativa geral
tabela_comparativa.to_csv('./csv_gerado/Tabela_Comparativa.csv', index=False)

# Criando e salvando tabelas específicas
tabela_distancia_carga = tabela_comparativa[['Origem', 'Estado', 'Distância hub carga', 'Distância original carga']]
tabela_distancia_comercial = tabela_comparativa[['Origem', 'Estado', 'Distância hub comercial', 'Distância original comercial']]
tabela_emissao_carga = tabela_comparativa[['Origem', 'Estado', 'Emissão hub carga', 'Emissão original carga']]
tabela_emissao_comercial = tabela_comparativa[['Origem', 'Estado', 'Emissão hub comercial', 'Emissão original comercial']]

# Salvando os arquivos CSV separados
tabela_distancia_carga.to_csv('./csv_gerado/Tabela_Distancia_Carga.csv', index=False)
tabela_distancia_comercial.to_csv('./csv_gerado/Tabela_Distancia_Comercial.csv', index=False)
tabela_emissao_carga.to_csv('./csv_gerado/Tabela_Emissao_Carga.csv', index=False)
tabela_emissao_comercial.to_csv('./csv_gerado/Tabela_Emissao_Comercial.csv', index=False)

# Exibindo como verificação
tabela_emissao_carga
# Out:
#                                                 Origem               Estado  \
# 0               Aeroporto Adolfo Suárez Madrid-Barajas                Bahia
# 1               Aeroporto Adolfo Suárez Madrid-Barajas                Ceará
# 2                   Aeroporto Internacional Don Mueang                Bahia
# 3                   Aeroporto Internacional Don Mueang              Paraíba
# 4    Aeroporto Internacional de Budapeste Ferenc Liszt                Bahia
# ..                                                 ...                  ...
# 99                        Aeroporto de Varsóvia Chopin             Maranhão
# 100                       Aeroporto de Varsóvia Chopin           Pernambuco
# 101                               Aeroporto de Zurique             Maranhão
# 102                               Aeroporto de Zurique           Pernambuco
# 103                               Aeroporto de Zurique  Rio Grande do Norte
#
#      Emissão hub carga  Emissão original carga
# ...

# %%
import pandas as pd

# Função para análise comparativa por estado
def analisar_por_estado(tabela_comparativa, tipo, metrica):
    """
    Analisa qual rota (original ou via hub) é melhor para cada estado com base na métrica fornecida.

    Parâmetros:
        tabela_comparativa (pd.DataFrame): Tabela contendo as distâncias ou emissões de CO2.
        tipo (str): 'carga' ou 'comercial', para diferenciar os tipos de transporte.
        metrica (str): 'Distância' ou 'Emissão', para definir a métrica de comparação.

    Retorna:
        analise (pd.DataFrame): DataFrame com a contagem de casos por estado.
        conclusao (str): Conclusão geral sobre qual rota é melhor.
    """

    col_original = f'{metrica} original {tipo}'
    col_hub = f'{metrica} hub {tipo}'

    # Verifica se as colunas necessárias existem na tabela
    if col_original not in tabela_comparativa.columns or col_hub not in tabela_comparativa.columns:
        raise ValueError(f"As colunas esperadas '{col_original}' e '{col_hub}' não foram encontradas na tabela.")

    # Garantindo que não haja NaN nos cálculos, usando .loc[:] para evitar SettingWithCopyWarning
    tabela_comparativa = tabela_comparativa.copy()  # Garante que estamos trabalhando com uma cópia
    tabela_comparativa.loc[:, col_original] = tabela_comparativa[col_original].fillna(float('inf'))
    tabela_comparativa.loc[:, col_hub] = tabela_comparativa[col_hub].fillna(float('inf'))

    # Agrupando por Estado e aplicando a análise sem incluir as colunas de agrupamento na função apply()
    analise = tabela_comparativa.groupby('Estado', as_index=False)[[col_original, col_hub]].apply(
        lambda x: pd.Series({
            'iguais': (x[col_original] == x[col_hub]).sum(),
            'hub_menor': (x[col_hub] < x[col_original]).sum(),
            'original_menor': (x[col_original] < x[col_hub]).sum()
        })
    )

    # Determinando a melhor rota para cada estado
    analise['Melhor rota'] = analise.apply(
        lambda x: 'Original' if x['original_menor'] >= x['hub_menor'] else 'Proposta',
        axis=1
    )

    # Determinando qual rota é melhor no geral
    total_original_menor = analise['original_menor'].sum()
    total_hub_menor = analise['hub_menor'].sum()

    conclusao = f"\nConclusão geral ({metrica} - {tipo}): " + (
        "A rota original é melhor." if total_original_menor >= total_hub_menor else "A rota via hub é melhor."
    )

    return analise, conclusao


# Executando a análise para cada caso
analise_emissao_carga, conclusao_emissao_carga = analisar_por_estado(tabela_emissao_carga, "carga", "Emissão")
analise_emissao_comercial, conclusao_emissao_comercial = analisar_por_estado(tabela_emissao_comercial, "comercial", "Emissão")

# %%
print(analise_emissao_carga)
print(conclusao_emissao_carga)
# Out:
#                 Estado  iguais  hub_menor  original_menor Melhor rota
# 0              Alagoas       0          0               4    Original
# 1                Bahia       0         29               0    Proposta
# 2                Ceará       0         17               0    Proposta
# 3             Maranhão       4          0               2    Original
# 4              Paraíba       2          7               5    Proposta
# 5           Pernambuco       0         17               0    Proposta
# 6                Piauí       3          0               1    Original
# 7  Rio Grande do Norte      11          0               0    Original
# 8              Sergipe       0          2               0    Proposta
#
# Conclusão geral (Emissão - carga): A rota via hub é melhor.

# %%
print(analise_emissao_comercial)
print(conclusao_emissao_comercial)
# Out:
#                 Estado  iguais  hub_menor  original_menor Melhor rota
# 0              Alagoas       0          0               4    Original
# 1                Bahia       0         29               0    Proposta
# 2                Ceará       0         17               0    Proposta
# 3             Maranhão       4          0               2    Original
# 4              Paraíba       2          7               5    Proposta
# 5           Pernambuco       0         17               0    Proposta
# 6                Piauí       3          0               1    Original
# 7  Rio Grande do Norte      11          0               0    Original
# 8              Sergipe       0          2               0    Proposta
#
# Conclusão geral (Emissão - comercial): A rota via hub é melhor.
